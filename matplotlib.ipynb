# %% [markdown]
# <a href="https://colab.research.google.com/github/annefrancine/Introduction-python/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib est une bibliothèque de Python qui constitue un puissant outil pour tracer et visualiser des données. Elle est destinée à produire des graphiques de toutes sortes (voir ici pour une galerie d'images produites avec Matplotlib).
#
# Matplotlib contient la sous-bibliothèque pyplot qui crée une interface proche de celle du logiciel commercial Matlab et qui contient des fonctions très similaires à celui-ci.
#
# Pour utiliser les fonctionnalités offertes par matplotlib, il est nécessaire de charger certains modules. Le plus commun est le sous-module pyplot, auquel on attribue fréquemment l’alias plt.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline (jupyter notebook)
import numpy as np
import pandas as pd

# %% [markdown]
# 1) Utilisation de plot()
#
# L’instruction plot() permet de tracer des courbes qui relient des points dont les abscisses et ordonnées sont fournies dans des tableaux.

# %%
x =np.arange(-10,11)
y= x**2
plt.plot(x,y);

# %% [markdown]
# 2) Utilisation de subplot()
#
# La fonction subplot() permet d’organiser différents tracés à l’intérieur d’une grille d’affichage. Il faut spécifier le nombre de lignes, le nombre de colonnes ainsi que le numéro du tracé.
#
# ![test_subplot_colonne.png](data:image/png;base64,...)
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.subplot(211)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(211)", ha="center", va="center", size=24, alpha=.5)
#
# plt.subplot(212)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(212)", ha="center", va="center", size=24, alpha=.5)
#
# plt.show()
# ```

# %% [markdown]
# ![test_subplot_ligne.png](data:image/png;base64,...)
#
#
#
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.subplot(121)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(121)", ha="center", va="center", size=24, alpha=.5)
#
# plt.subplot(122)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(122)", ha="center", va="center", size=24, alpha=.5)
#
# plt.show()
# ```

# %% [markdown]
# ![test_subplot_grille.png](data:image/png;base64,...)
#
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.subplot(221)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(221)", ha="center", va="center", size=24, alpha=.5)
#
# plt.subplot(222)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(222)", ha="center", va="center", size=24, alpha=.5)
#
# plt.subplot(223)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(223)", ha="center", va="center", size=24, alpha=.5)
#
# plt.subplot(224)
# plt.xticks([])
# plt.yticks([])
# plt.text(0.5, 0.5, "subplot(224)", ha="center", va="center", size=24, alpha=.5)
#
# plt.show()
# ```

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.subplot(211)
plt.plot(t1, f(t1), "bo")
plt.plot(t2, f(t2), "k")

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), "r--")
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

plt.subplot(321)
plt.scatter(x, y, s=80, c=z, marker=">")

plt.subplot(322)
plt.scatter(x, y, s=80, c=z, marker=(5, 0))

verts = np.array([[-1, -1], [1, -1], [1, 1], [-1, -1]])
plt.subplot(323)
plt.scatter(x, y, s=80, c=z, marker=verts)

plt.subplot(324)
plt.scatter(x, y, s=80, c=z, marker=(5, 1))

plt.subplot(325)
plt.scatter(x, y, s=80, c=z, marker='+')

plt.subplot(326)
plt.scatter(x, y, s=80, c=z, marker=(5, 2))

plt.show()

# %%
plt.figure(1)
plt.subplot(1, 2, 1)
plt.scatter(range(5), [x ** 2 for x in range(5)], color = 'blue')
plt.subplot(2, 2, 2)
plt.plot(range(5), color = 'red')
plt.subplot(2, 2, 4)
plt.bar(range(5), range(5), color = 'green');

# %% [markdown]
# 3) Définition du domaine des axes - xlim() et ylim()
#
# Il est possible fixer indépendamment les domaines des abscisses et des ordonnées en utilisant les fonctions xlim() et ylim()
#
# ```
# x(xmin, xmax)
# ylim(ymin, ymax)
# ```

# %%
N = 8
y = np.zeros(N)
x1 = np.linspace(0, 10, N, endpoint=True)
x2 = np.linspace(0, 10, N, endpoint=False)
plt.plot(x1, y, 'o')
plt.plot(x2, y + 0.5, 'o')
plt.ylim([-0.5, 1])
plt.show()

# %% [markdown]
# 4) Ajout d’un titre - title()
#
# On peut ajouter un titre grâce à l’instruction title()

# %%
x = np.linspace(0, 2*np.pi, 30)
y = np.cos(x)
plt.plot(x, y)
plt.title("Fonction cosinus")

plt.show()

# %% [markdown]
# 5)Ajout d’une légende - legend()

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index = ['a', 'b', 'c'])
plts =plt.plot(df, marker = 'o')
plt.legend(plts, df.columns)
plt.show()

# %% [markdown]
# 6) Labels sur les axes - xlabel() et ylabel()
#
# - ylabel : Définit l'étiquette de l'axe des ordonnées.
# - xlabel peut être utilisé pour définir l'étiquette de l'axe X.

# %%
x = np.linspace(0, 2*np.pi, 30)
y = np.cos(x)
plt.plot(x, y)
plt.xlabel("abscisses")
plt.ylabel("ordonnees")

plt.show()

# %% [markdown]
# 7) Formats de courbes
#
# Il est possible de préciser la couleur, le style de ligne et de symbole (« marker ») en ajoutant une chaîne de caractères de la façon suivante :

# %%
x = np.linspace(0, 2*np.pi, 30)
y1 = np.cos(x)
y2 = np.sin(x)
plt.plot(x, y1, "r--", label="cos(x)")
plt.plot(x, y2, "b:o", label="sin(x)")
plt.legend()

plt.show()

# %% [markdown]
# Pour chaque paire (x,y) d'arguments, il y a un troisième argument optionnel qui est une chaîne de caractères qui indique le style et la couleur de la ligne de la courbe. Les styles de courbes possibles sont:
#
# •	'-' : ligne continue
#
# •	'--' : tirets
#
# •	':' : ligne en pointillé
#
# •	'-.' : tirets points
#
# Il est également possible d'ajouter des marqueurs de points à l'aide de symboles, que l'on peut rajouter aux lignes de courbes ou utiliser à la place des lignes . Ces symboles peuvent également être concaténés avec les couleurs présentées ci-dessus. Les symboles possibles sont:
#
# •	'.' : point marker
#
# •	',' : pixel marker
#
# •	'o' : circle marker
#
# •	'v' : triangle_down marker
#
# •	'^' : triangle_up marker
#
# •	'<' : triangle_left marker
#
# •	'>' : triangle_right marker
#
# •	'1' : tri_down marker
#
# •	'2' : tri_up marker
#
# •	'3' : tri_left marker
#
# •	'4' : tri_right marker
#
# •	's' : square marker
#
# •	'p' : pentagon marker
#
# •	'*' : star marker
#
# •	'h' : hexagon1 marker
#
# •	'H' : hexagon2 marker
#
# •	'+' : plus marker
#
# •	'x' : x marker
#
# •	'D' : diamond
#
# •	'd' : thin_diamond marker
#
# •	'|' : vline
#
# •	'_' : hline marker

# %%
x = np.linspace(0, 2*np.pi, 20)
y = np.sin(x)
plt.plot(x, y, "o-", label="ligne -")
plt.plot(x, y-0.5, "o--", label="ligne --")
plt.plot(x, y-1, "o:", label="ligne :")
plt.plot(x, y-1.5, "o-.", label="ligne -.")
plt.plot(x, y-2, "o", label="pas de ligne")
plt.legend()

plt.show()

# %% [markdown]
# 8) L’instruction axis("equal")
#
# L’instruction axis("equal") permet d’avoir la même échelle sur l’axe des abscisses et l’axe des ordonnées afin de préserver la forme lors de l’affichage. En particulier, grâce à cette commande un carré apparaît vraiment comme un carré, de même pour un cercle.

# %%
x = np.array([0, 1, 1, 0, 0])
y = np.array([0, 0, 1, 1, 0])
plt.plot(x, y)
plt.axis("equal")

plt.show()

# %% [markdown]
# 9) BarPlots: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html
#
# La méthode plt.bar permet de tracer des diagrammes en barres, verticaux avec une seule ou plusieurs séries de valeurs : Pour afficher un bar plot il suffit d'entrer dans la méthode en premier argument les positions de début de chaque barre sur l'axe des x, et en second argument les hauteurs des barres.
# Les paramètres supplémentaires les plus importants sont la couleur à l'intérieur des barres (color) et la largeur relative de chaque barre (width par défaut 0.8, c'est à dire 20% d'espace vide entre chaque barre).
# Comme toutes les fonctions de pyplot il existe beaucoup d'autres paramètres comme :
#
# •	edgecolor : la couleur des encadrements.
#
# •	linewidth : l'épaisseur des traits.
#
# •	yerr : les valeurs des barres d'erreur.
#
# •	ecolor : la couleur des barres d'erreur.
#
# •	orientation : 'horizontal' pour afficher un barplot horizontal.
#
# •	hatch = '/' : les hachures. Valeurs possibles : '/', '\', '|', '-', '+', 'x', 'o', 'O', '.', '*'.

# %%
plt.bar(range(5), [1, 3, 3, 5, 4], width = 0.5, color = 'red')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Parmi tous les paramètres existants, yerr permet d'ajouter des barres d'Erreurs aux barres du graphiques. Pour les ajouter il suffit d'entrer dans le paramètre yerr la taille des barres d'erreurs que l'on souhaite.  ecolor permet de choisir la couleur de ces barres d'erreurs.

# %%
plt.bar(range(5), [1, 3, 3, 5, 4], width = 0.6, color = 'yellow',
  edgecolor = 'blue', linewidth = 2, yerr = [0.5, 1, 2, 1, 2],
  ecolor = 'magenta', capsize = 10)
plt.xticks(range(5), ['A', 'B', 'C', 'D', 'E'],
  rotation = 45);

# %%
# Exemple de barplot avec 2 séries de données :

barWidth = 0.4
y1 = [1, 2, 4, 3]
y2 = [3, 4, 4, 3]
r1 = range(len(y1))
r2 = [x + barWidth for x in r1]

plt.bar(r1, y1, width = barWidth, color = ['yellow' for i in y1],
           edgecolor = ['blue' for i in y1], linewidth = 2)
plt.bar(r2, y2, width = barWidth, color = ['pink' for i in y1],
           edgecolor = ['green' for i in y1], linewidth = 4)
plt.xticks([r + barWidth / 2 for r in range(len(y1))], ['A', 'B', 'C', 'D']);

# %%
# Exemple de barplot avec 2 séries superposées :

barWidth = 0.8
y1 = [1, 2, 4, 3]
y2 = [3, 4, 4, 3]
r = range(len(y1))

plt.bar(r, y1, width = barWidth, color = ['yellow' for i in y1],
           edgecolor = ['blue' for i in y1], linestyle = 'solid', hatch ='/',
           linewidth = 3)
plt.bar(r, y2, width = barWidth, bottom = y1, color = ['pink' for i in y1],
           edgecolor = ['green' for i in y1], linestyle = 'dotted', hatch = 'o',
           linewidth = 3)
plt.xticks(range(len(y1)), ['A', 'B', 'C', 'D']);

# %%
# Barplot horizontal(on utilise barh, en remplaçant width par height et bottom par left)

barWidth = 0.8
y1 = [1, 2, 4, 3]
y2 = [3, 4, 4, 3]
r = range(len(y1))

plt.barh(r, y1, height = barWidth, color = ['yellow' for i in y1],
           edgecolor = ['blue' for i in y1], linestyle = 'solid', hatch ='/',
           linewidth = 3)
plt.barh(r, y2, height = barWidth, left = y1, color = ['pink' for i in y1],
           edgecolor = ['green' for i in y1], linestyle = 'dotted', hatch = 'o',
           linewidth = 3)
plt.yticks(range(len(y1)), ['A', 'B', 'C', 'D']);

# %%
plt.figure(figsize=(8, 6), dpi=80)
n = 15
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x, y in zip(X, Y1):
    plt.text(x, y + 0.05, '%.2f' % y,
             ha='center', va='bottom')
for x, y in zip(X, Y2):
    plt.text(x, -y - 0.10, '%.2f' % y,
             ha='center', va='bottom')

plt.ylim(-1.25, +1.25)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# 10)	Scatter plot (nuage de points) : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
#
# La méthode scatter permet de tracer des nuages de points, elle s'utilise d'une manière similaire à plot.

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 3, 4, 5]
y2 = [1, 4, 9, 16, 25]
plt.scatter(x, y1, c = 'red')
plt.scatter(x, y2, c = 'yellow');

# %% [markdown]
# 11) Histogrammes : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
#
# La méthode plt.hist permet d'afficher des histogrammes, en lui donnant en arguments:
# •	Une série de valeurs (x) ,
#
# •	Les bornes des valeurs à utiliser (range: par défaut (min(x), max(x)) )
#
# •	Le nombre d'intervalles (bins) ou les limites explicites des intervalles.
#
# Dans le cas où le nombre d'intervalles est le seul élément renseigné, ceux-ci seront de tailles égales, mais des intervalles de tailles différentes sont possibles lorsqu'ils sont renseignés explicitement.

# %%
plt.hist(x, range = (0, 5), bins = 5, color = 'yellow',
            edgecolor = 'red')
plt.xlabel('valeurs')
plt.ylabel('nombres')
plt.title('Exemple d\' histogramme simple');

# %%
# Affichage de l'histogramme de 2 séries (les 2 couleurs sont obligatoires, par contre la couleur des bordures et les rayures ne sont communs)
x1 = [1, 2, 2, 3, 4, 4, 4, 4, 4, 5, 5]
x2 = [1, 1, 1, 2, 2, 3, 3, 3, 3, 4, 5, 5, 5]
bins = [x + 0.5 for x in range(0, 6)]
plt.hist([x1, x2], bins = bins, color = ['yellow', 'green'],
            edgecolor = 'red', hatch = '/', label = ['x1', 'x2'],
            histtype = 'bar') # bar est le defaut
plt.ylabel('valeurs')
plt.xlabel('nombres')
plt.title('2 series')
plt.legend();

# %%
# Affichage de l'histogramme de 2 séries, mais sous forme superposées, l'un au dessus de l'autre.

x1 = [1, 2, 2, 3, 4, 4, 4, 4, 4, 5, 5]
x2 = [1, 1, 1, 2, 2, 3, 3, 3, 3, 4, 5, 5, 5]
bins = [x + 0.5 for x in range(0, 6)]
plt.hist([x1, x2], bins = bins, color = ['yellow', 'green'],
            edgecolor = 'red', hatch = '/', label = ['x1', 'x2'],
            histtype = 'barstacked')
plt.ylabel('valeurs')
plt.xlabel('nombres')
plt.title('2 series superposees')
plt.legend();

# %% [markdown]
# 12) Boxplot (boîte à moustache) : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# La commande plt.boxplot permet d'afficher des boites à moustaches sur un graphique. Elle prend en argument une séquence de séquences de valeurs.
# La boîte bleue donne les limites du premier et dernier quartile, la barre du milieu rouge donne la médiane.

# %%
plt.boxplot([[1, 2, 3, 4, 5], [7, 5, 8, 4, 9, 5, 7]]);

# %%
# Pour avoir des boîtes remplies avec une couleur, utiliser des patchs plutôt que des lignes, et ensuite fixer leur couleur :
bp = plt.boxplot([[1, 2, 3, 4, 5, 13], [6, 7, 8, 10, 10, 11, 12], [1, 2, 3]], patch_artist = True)
for patch in bp['boxes']:
  patch.set_color('skyblue')
  patch.set_edgecolor('blue')

# %% [markdown]
# 13)	Camembert (Pie Charts) : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html
#
# Les camemberts sont des diagrammes circulaires divisés par secteurs (wedges). C'est une manière efficace de représenter l'information lorsque l'on s'intéresse principalement à la comparaison d'un secteur avec le camembert tout entier plutôt qu'entre deux secteurs.
#
# La méthode pie permet de tracer des diagrammes circulaires à partir d'une séquence X.
# Chaque élément xi de X est représenté par une part proportionnelle à xi/sum(X). Si la somme des éléments de X est inférieure à 1, le camembert est représenté à l'aide des valeurs de X directement, aucune normalisation n'est effectuée, ce qui laisse un espace vide

# %%
plt.pie(x, labels = ['A', 'B', 'C', 'D', 'E'])
plt.figure(figsize = (8, 8))
x = [1, 2, 3, 4, 10]
plt.pie(x, labels = ['A', 'B', 'C', 'D', 'E'])
plt.legend();

# %% [markdown]
# 14) Heatmap
#
# Une heat map, ou heatmap, carte de fréquentation en Français, est une représentation graphique de données statistiques qui fait correspondre à l'intensité d'une grandeur variable une gamme de tons ou un nuancier de couleurs sur une matrice à deux dimensions

# %%
a = np.random.random((16, 16))
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show();

# %%
import seaborn as sns
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data, linewidth=0.5)
plt.show();

# %% [markdown]
# 15) Stem plot
#
# Graphe qui représente une barre verticale par point à la coordonnée indiquée

# %%
plt.stem(range(5), [x ** 2 for x in range(5)],
            markerfmt = 'ro', linefmt = 'g--', basefmt = 'm:', use_line_collection = True)
plt.margins(0.1, 0.1)
plt.title('stem avec configuration simple')
plt.ylabel('valeurs');

# %% [markdown]
# 16) 	Polar charts : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.polar.html
#
# Les graphiques polaires utilisent un système de coordonnées complètement différent. Jusqu'à présent, nous avons utilisé le système cartésien, où 2 lignes perpendiculaires se rencontrent à l'origine des axes avec des directions précises pour déterminer les valeurs positives et négatives. Un système polair est un système de coordonnées à deux dimensions, où la position d'un point est exprimée en termes de radius et angle. Ce système est utilisé lorsque la relation entre deux points est mieux exprimée en utilisant ces informations.

# %%
plt.figure(figsize=(8, 8), dpi=60)

ax = plt.axes([0.025, 0.025, 0.95, 0.95], polar=True)

N = 20
theta = np.arange(0, 2 * np.pi, 2 * np.pi / N)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)

for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show();

# %% [markdown]
# 17) Contour plots : https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.contour.html
#
# La fonction plt.contour() permet de tracer des courbes de niveaux.
# En particulier, pour une fonction à deux variables on parle de lignes de niveaux, qui sont des courbes sur lesquelles la fonction a une valeur constante. Mathématiquement, c'est un graphique qui représente f(x, y) = L, pour différentes constantes L.

# %%
plt.figure(figsize=(8, 6), dpi=80)

def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * \
           np.exp(-x ** 2 -y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap='jet')
C = plt.contour(X, Y, f(X, Y), 8, colors='black')
